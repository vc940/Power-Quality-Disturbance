# %%
import pandas as pd
import numpy as np
import os

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

# %%
files = os.listdir("/kaggle/input/seed-power-quality-disturbance-dataset/XPQRS")
files = [i for i in files if i[-3:]== "csv"]

# %%
files
# Out:
# ['Pure_Sinusoidal.csv',
#  'Swell_with_Harmonics.csv',
#  'Transient.csv',
#  'Harmonics.csv',
#  'Harmonics_with_Sag.csv',
#  'Swell.csv',
#  'Swell_with_Oscillatory_Transient.csv',
#  'Sag.csv',
#  'Interruption.csv',
#  'Flicker.csv',
#  'Harmonics_with_Swell.csv',
#  'Flicker_with_Swell.csv',
#  'Notch.csv',
#  'Flicker_with_Sag.csv',
#  'Sag_with_Harmonics.csv',
#  'Oscillatory_Transient.csv',
#  'Sag_with_Oscillatory_Transient.csv']

# %%
def compute_fft_features(signal, sampling_rate=1.0, n_features=10):
    """
    Compute top n_features magnitudes and their corresponding frequencies.
    """
    n = len(signal)
    fft_vals = np.fft.fft(signal)
    fft_freqs = np.fft.fftfreq(n, d=1/sampling_rate)

    # Keep only the positive half (real signal)
    half_n = n 
    fft_magnitudes = np.abs(fft_vals[:half_n])
    fft_freqs = fft_freqs[:half_n]
    # Select top `n_features` based on magnitude

    top_indices = np.argsort(fft_magnitudes)[-n_features:]
    top_magnitudes = fft_magnitudes[top_indices]
    top_frequencies = fft_freqs[top_indices]

    return top_magnitudes, top_frequencies

# %%
data = []
labels = []
for idx,i in enumerate(files):
    path = "/kaggle/input/seed-power-quality-disturbance-dataset/XPQRS"
    csv = os.path.join(path,i)
    df = pd.read_csv(csv)
    for _,row in df.iterrows():
        seq = row.values.astype(np.float32)
        
        mag,freq = compute_fft_features(seq,sampling_rate = 5000,n_features = 100)
        mag,freq = mag.astype(float),freq.astype(float)
        features = np.array([seq,mag,freq])
        data.append(features)
        labels.append(idx)

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Reshape to 2D array as required by sklearn
labels = np.array(labels).reshape(-1, 1)

encoder = OneHotEncoder(sparse=False)  # use sparse=True for sparse matrix
onehot_labels = encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
len(data)
# Out:
# 16983

# %%
class dataload(Dataset):
    def __init__(self,X_train,Y_train):
        super().__init__()
        self.x = X_train
        self.y = Y_train
    def __len__(self):
        return len(self.x)
    def __getitem__(self,idx):
        return self.x[idx],self.y[idx]

# %%
dataset = dataload(data,onehot_labels)

# %%
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)
        )
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # shape: (1, max_len, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return x
class TimeSeriesTransformer(nn.Module):
    def __init__(self, input_dim=3, model_dim=64, num_heads=4, num_layers=2, dropout=0.1):
        super(TimeSeriesTransformer, self).__init__()
        self.input_projection = nn.Linear(input_dim, model_dim)
        self.positional_encoding = PositionalEncoding(model_dim)
        
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=num_heads,
            dropout=dropout,
            batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        self.output_layer = nn.Linear(model_dim, 17)  # output_dim = 1 for regression

    def forward(self, x):
        # x shape: (batch_size, seq_len, input_dim)
        x = self.input_projection(x)
        x = self.positional_encoding(x)
        x = self.transformer_encoder(x)
        x = x.mean(dim=1)               
        return self.output_layer(x)

# %%
model = TimeSeriesTransformer().to("cuda")
optimizer = Adam(model.parameters(),lr=0.0001)
loss_fn = nn.CrossEntropyLoss()

# %%
device = torch.device("cuda")

# %%
from sklearn.model_selection import train_test_split

train_data,test_data = train_test_split(dataset,test_size = 0.1)

# %%
train_loader = DataLoader(train_data,batch_size = 256,shuffle = True)
test_loader = DataLoader(test_data,batch_size = 256,shuffle = True)




for epoch in range(100):
    model.train()
    running_loss = 0.0
    for inputs, targets in train_loader:
        inputs = inputs.to(device)

        targets = targets.to(device)
        optimizer.zero_grad()
        inputs = inputs.permute(0,2,1)
        inputs = inputs.float()
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch {epoch+1},Traning Loss: {running_loss / len(train_loader):.4f}")
    running_loss = 0.0
    for inputs, targets in test_loader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        inputs  = inputs.permute(0,2,1)
        inputs = inputs.float()
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        running_loss += loss.item()

    print(f"Epoch {epoch+1}, Validation Loss: {running_loss / len(test_loader):.4f}")
# Out:
# Epoch 1,Traning Loss: 0.2615
# Epoch 1, Validation Loss: 0.4025
# Epoch 2,Traning Loss: 0.2775
# Epoch 2, Validation Loss: 0.4040
# Epoch 3,Traning Loss: 0.2917
# Epoch 3, Validation Loss: 0.4199
# Epoch 4,Traning Loss: 0.2761
# Epoch 4, Validation Loss: 0.4033
# Epoch 5,Traning Loss: 0.2718
# Epoch 5, Validation Loss: 0.3911
# Epoch 6,Traning Loss: 0.2815
# Epoch 6, Validation Loss: 0.4129
# Epoch 7,Traning Loss: 0.2696
# Epoch 7, Validation Loss: 0.4017
# Epoch 8,Traning Loss: 0.2691
# Epoch 8, Validation Loss: 0.4233
# Epoch 9,Traning Loss: 0.2782
# Epoch 9, Validation Loss: 0.3910
# Epoch 10,Traning Loss: 0.2675
# Epoch 10, Validation Loss: 0.3940
# Epoch 11,Traning Loss: 0.2655
# Epoch 11, Validation Loss: 0.4088
# Epoch 12,Traning Loss: 0.2780
# Epoch 12, Validation Loss: 0.4271
# Epoch 13,Traning Loss: 0.2728
# Epoch 13, Validation Loss: 0.3933
# Epoch 14,Traning Loss: 0.2805
# Epoch 14, Validation Loss: 0.4013
# Epoch 15,Traning Loss: 0.2601
# Epoch 15, Validation Loss: 0.3982
# Epoch 16,Traning Loss: 0.2746
# Epoch 16, Validation Loss: 0.4182
# Epoch 17,Traning Loss: 0.2756
# Epoch 17, Validation Loss: 0.4349
# Epoch 18,Traning Loss: 0.2732
# Epoch 18, Validation Loss: 0.4361
# Epoch 19,Traning Loss: 0.2713
# Epoch 19, Validation Loss: 0.4287
# Epoch 20,Traning Loss: 0.2962
# Epoch 20, Validation Loss: 0.3980
# Epoch 21,Traning Loss: 0.2684
# Epoch 21, Validation Loss: 0.4110
# Epoch 22,Traning Loss: 0.2598
# Epoch 22, Validation Loss: 0.4160
# Epoch 23,Traning Loss: 0.2697
# Epoch 23, Validation Loss: 0.4920
# Epoch 24,Traning Loss: 0.2746
# Epoch 24, Validation Loss: 0.3822
# Epoch 25,Traning Loss: 0.2642
# Epoch 25, Validation Loss: 0.3880
# Epoch 26,Traning Loss: 0.2668
# Epoch 26, Validation Loss: 0.4056
# Epoch 27,Traning Loss: 0.2507
# Epoch 27, Validation Loss: 0.4116
# Epoch 28,Traning Loss: 0.2742
# Epoch 28, Validation Loss: 0.4142
# Epoch 29,Traning Loss: 0.2600
# Epoch 29, Validation Loss: 0.3958
# Epoch 30,Traning Loss: 0.2537
# Epoch 30, Validation Loss: 0.4087
# Epoch 31,Traning Loss: 0.2597
# Epoch 31, Validation Loss: 0.3705
# Epoch 32,Traning Loss: 0.2580
# Epoch 32, Validation Loss: 0.4023
# Epoch 33,Traning Loss: 0.2639
# Epoch 33, Validation Loss: 0.4606
# Epoch 34,Traning Loss: 0.2596
# Epoch 34, Validation Loss: 0.4015
# Epoch 35,Traning Loss: 0.2572
# Epoch 35, Validation Loss: 0.4043
# Epoch 36,Traning Loss: 0.2957
# Epoch 36, Validation Loss: 0.4222
# Epoch 37,Traning Loss: 0.2651
# Epoch 37, Validation Loss: 0.3913
# Epoch 38,Traning Loss: 0.2613
# Epoch 38, Validation Loss: 0.3955
# Epoch 39,Traning Loss: 0.2561
# Epoch 39, Validation Loss: 0.4103
# Epoch 40,Traning Loss: 0.2569
# Epoch 40, Validation Loss: 0.3879
# Epoch 41,Traning Loss: 0.2561
# Epoch 41, Validation Loss: 0.4135
# Epoch 42,Traning Loss: 0.2682
# Epoch 42, Validation Loss: 0.4067
# Epoch 43,Traning Loss: 0.2628
# Epoch 43, Validation Loss: 0.3957
# Epoch 44,Traning Loss: 0.2610
# Epoch 44, Validation Loss: 0.3999
# Epoch 45,Traning Loss: 0.2548
# Epoch 45, Validation Loss: 0.3969
# Epoch 46,Traning Loss: 0.2752
# Epoch 46, Validation Loss: 0.4264
# Epoch 47,Traning Loss: 0.2593
# Epoch 47, Validation Loss: 0.3945
# Epoch 48,Traning Loss: 0.2662
# Epoch 48, Validation Loss: 0.4058
# Epoch 49,Traning Loss: 0.2626
# Epoch 49, Validation Loss: 0.4489
# Epoch 50,Traning Loss: 0.2804
# Epoch 50, Validation Loss: 0.3889
# Epoch 51,Traning Loss: 0.2632
# Epoch 51, Validation Loss: 0.4102
# Epoch 52,Traning Loss: 0.2700
# Epoch 52, Validation Loss: 0.3955
# Epoch 53,Traning Loss: 0.2681
# Epoch 53, Validation Loss: 0.3745
# Epoch 54,Traning Loss: 0.2551
# Epoch 54, Validation Loss: 0.4050
# Epoch 55,Traning Loss: 0.2575
# Epoch 55, Validation Loss: 0.4061
# Epoch 56,Traning Loss: 0.2673
# Epoch 56, Validation Loss: 0.4219
# Epoch 57,Traning Loss: 0.2478
# Epoch 57, Validation Loss: 0.3976
# Epoch 58,Traning Loss: 0.2670
# Epoch 58, Validation Loss: 0.4138
# Epoch 59,Traning Loss: 0.2532
# Epoch 59, Validation Loss: 0.3910
# Epoch 60,Traning Loss: 0.2561
# Epoch 60, Validation Loss: 0.4061
# Epoch 61,Traning Loss: 0.2562
# Epoch 61, Validation Loss: 0.3926
# Epoch 62,Traning Loss: 0.2706
# Epoch 62, Validation Loss: 0.4278
# Epoch 63,Traning Loss: 0.2625
# Epoch 63, Validation Loss: 0.4293
# Epoch 64,Traning Loss: 0.2508
# Epoch 64, Validation Loss: 0.4274
# Epoch 65,Traning Loss: 0.2574
# Epoch 65, Validation Loss: 0.4360
# Epoch 66,Traning Loss: 0.2542
# Epoch 66, Validation Loss: 0.3816
# Epoch 67,Traning Loss: 0.2559
# Epoch 67, Validation Loss: 0.3918
# Epoch 68,Traning Loss: 0.2553
# Epoch 68, Validation Loss: 0.4077
# Epoch 69,Traning Loss: 0.2511
# Epoch 69, Validation Loss: 0.4004
# Epoch 70,Traning Loss: 0.2552
# Epoch 70, Validation Loss: 0.3987
# Epoch 71,Traning Loss: 0.2517
# Epoch 71, Validation Loss: 0.3859
# Epoch 72,Traning Loss: 0.2567
# Epoch 72, Validation Loss: 0.3807
# Epoch 73,Traning Loss: 0.2489
# Epoch 73, Validation Loss: 0.4120
# Epoch 74,Traning Loss: 0.2478
# Epoch 74, Validation Loss: 0.4365
# Epoch 75,Traning Loss: 0.2495
# Epoch 75, Validation Loss: 0.4035
# Epoch 76,Traning Loss: 0.2502
# Epoch 76, Validation Loss: 0.4100
# Epoch 77,Traning Loss: 0.2594
# Epoch 77, Validation Loss: 0.4217
# Epoch 78,Traning Loss: 0.2585
# Epoch 78, Validation Loss: 0.3772
# Epoch 79,Traning Loss: 0.2482
# Epoch 79, Validation Loss: 0.4034
# Epoch 80,Traning Loss: 0.2437
# Epoch 80, Validation Loss: 0.3924
# Epoch 81,Traning Loss: 0.2522
# Epoch 81, Validation Loss: 0.4110
# Epoch 82,Traning Loss: 0.2563
# Epoch 82, Validation Loss: 0.3892
# Epoch 83,Traning Loss: 0.2477
# Epoch 83, Validation Loss: 0.4051
# Epoch 84,Traning Loss: 0.2757
# Epoch 84, Validation Loss: 0.3910
# Epoch 85,Traning Loss: 0.2532
# Epoch 85, Validation Loss: 0.3927
# Epoch 86,Traning Loss: 0.2562
# Epoch 86, Validation Loss: 0.3980
# Epoch 87,Traning Loss: 0.2507
# Epoch 87, Validation Loss: 0.4058
# Epoch 88,Traning Loss: 0.2533
# Epoch 88, Validation Loss: 0.3925
# Epoch 89,Traning Loss: 0.2414
# Epoch 89, Validation Loss: 0.4308
# Epoch 90,Traning Loss: 0.2557
# Epoch 90, Validation Loss: 0.3986
# Epoch 91,Traning Loss: 0.2577
# Epoch 91, Validation Loss: 0.3846
# Epoch 92,Traning Loss: 0.3397
# Epoch 92, Validation Loss: 0.4402
# Epoch 93,Traning Loss: 0.2645
# Epoch 93, Validation Loss: 0.4175
# Epoch 94,Traning Loss: 0.2485
# Epoch 94, Validation Loss: 0.4059
# Epoch 95,Traning Loss: 0.2753
# Epoch 95, Validation Loss: 0.4281
# Epoch 96,Traning Loss: 0.2482
# Epoch 96, Validation Loss: 0.4169
# Epoch 97,Traning Loss: 0.2457
# Epoch 97, Validation Loss: 0.4158
# Epoch 98,Traning Loss: 0.2527
# Epoch 98, Validation Loss: 0.3947
# Epoch 99,Traning Loss: 0.2455
# Epoch 99, Validation Loss: 0.4076
# Epoch 100,Traning Loss: 0.2594
# Epoch 100, Validation Loss: 0.4055

# %%
# Save the model's state_dict
torch.save(model.state_dict(), 'model_weights2.pth')

# %%
import torch
import numpy as np

# Assuming: model, test_loader, and device are already defined
model.eval()

n_classes = 17
class_correct = [0 for _ in range(n_classes)]
class_total = [0 for _ in range(n_classes)]

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        inputs = inputs.permute(0,2,1)
        inputs = inputs.float()

        outputs = model(inputs)
        preds = torch.argmax(outputs, dim=1)
        labels = torch.argmax(labels,dim = 1)
        for i in range(len(labels)):
            label = labels[i].item()
            pred = preds[i].item()
            if label == pred:
                class_correct[label] += 1
            class_total[label] += 1

# Print class-wise accuracy
for i in range(n_classes):
    accuracy = 100 * class_correct[i] / class_total[i] if class_total[i] > 0 else 0
    print(f"Class {i}: Accuracy = {accuracy:.2f}%")
print(class_total)
# Out:
# Class 0: Accuracy = 100.00%
# Class 1: Accuracy = 59.22%
# Class 2: Accuracy = 96.40%
# Class 3: Accuracy = 100.00%
# Class 4: Accuracy = 76.84%
# Class 5: Accuracy = 100.00%
# Class 6: Accuracy = 77.78%
# Class 7: Accuracy = 97.70%
# Class 8: Accuracy = 81.82%
# Class 9: Accuracy = 100.00%
# Class 10: Accuracy = 91.21%
# Class 11: Accuracy = 78.00%
# Class 12: Accuracy = 93.81%
# Class 13: Accuracy = 67.95%
# Class 14: Accuracy = 44.86%
# Class 15: Accuracy = 86.14%
# Class 16: Accuracy = 84.54%
# [106, 103, 111, 111, 95, 114, 99, 87, 99, 103, 91, 100, 97, 78, 107, 101, 97]

# %%
Class 0: Accuracy = 100.00%
Class 1: Accuracy = 12.62%
Class 2: Accuracy = 95.50%
Class 3: Accuracy = 99.10%
Class 4: Accuracy = 24.21%
Class 5: Accuracy = 99.12%
Class 6: Accuracy = 32.32%
Class 7: Accuracy = 80.46%
Class 8: Accuracy = 98.99%
Class 9: Accuracy = 100.00%
Class 10: Accuracy = 57.14%
Class 11: Accuracy = 55.00%
Class 12: Accuracy = 81.44%
Class 13: Accuracy = 37.18%
Class 14: Accuracy = 23.36%
Class 15: Accuracy = 83.17%
Class 16: Accuracy = 31.96%

# %%
['Pure_Sinusoidal.csv',
 'Swell_with_Harmonics.csv',
 'Transient.csv',
 'Harmonics.csv',
 'Harmonics_with_Sag.csv',
 'Swell.csv',
 'Swell_with_Oscillatory_Transient.csv',
 'Sag.csv',
 'Interruption.csv',
 'Flicker.csv',
 'Harmonics_with_Swell.csv',
 'Flicker_with_Swell.csv',
 'Notch.csv',
 'Flicker_with_Sag.csv',
 'Sag_with_Harmonics.csv',
 'Oscillatory_Transient.csv',
 'Sag_with_Oscillatory_Transient.csv']
